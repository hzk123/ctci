# %%
# N-gram tfidf 
# have not drop stopword 
# have dropping digits
"""
EQB = [ [EQB item] * number of EQB item] 
[EQB item] = [ [paragraph1 in ITB1] , [ paragraph2 in ITB2] , [paragraph3 in ITB3] ] 
"""

#only use EOEG,NC6,JGS,liwa as training data
#use PTT_LNG as valid data 


import pandas as pd
import numpy as np
import nltk
import math
import re

# %%
pd_EOEG = pd.read_excel('EQB.xlsx',sheet_name = 'EOEG' );
pd_NC6 = pd.read_excel("EQB.xlsx",sheet_name='NC6');
pd_JGS = pd.read_excel("EQB.xlsx",sheet_name= 'JGS' );
pd_liwa = pd.read_excel("EQB.xlsx",sheet_name= 'LIWA' );
pd_PTT = pd.read_excel("EQB.xlsx",sheet_name= 'PTT LNG' );

# %%
EQB = [ [] for i in range(406) ];

def add_EQB(df):
    check = df['paragraph'].isna();
    for i in range(len(df)): 
        if check[i] == False:
            EQB[i].append(df['paragraph'][i])

add_EQB(pd_NC6);
add_EQB(pd_EOEG);
add_EQB(pd_JGS);
add_EQB(pd_liwa);

# %%
from nltk.corpus import stopwords

from nltk.stem import SnowballStemmer
import  nltk;
import math;
from nltk.stem import PorterStemmer
stopword_list = list(set(stopwords.words('english')));
stopword_list.append(',');
stopword_list.append(')');
stopword_list.append('(');
stopword_list.append('.');
stopword_list.append('-');

stemmer = SnowballStemmer('english')

# %%
def preprocess_paragraph(paragraph):
    raw_words = nltk.word_tokenize(paragraph); #tokenize words by nltk
    words = [w for w in raw_words if not w in stopword_list] #  drop stopword
    words = [stemmer.stem(w) for w in words]
    
    drop_digit = []
    for w in words:
        if re.findall(r'^[^\d]\w+',w):
            after = re.findall(r'^\w+$',w);
            if len(after) > 0:
                drop_digit.append(after[0])
            
    return drop_digit;

# %%
def update_dic(key , dic): #dictnary中令一个key的value+1
    if key not in dic:
        dic[key] = 1;
    else: 
        dic[key] += 1;
    return dic

# %%
def get_tf(EQB_field , df):
    num_words = 0;
    freq = {};
    for paragraph in EQB_field:
        words = preprocess_paragraph(paragraph)
        num_words += len(words) # calculate the total number of these paragraphs
        for w in words:
            freq = update_dic( key = w , dic = freq) # calculate tf
    tf = {}        
    for (word , count) in freq.items():
        tf[word] = count * 1.0 / num_words; # 修正每个词为正确的频率
        df = update_dic( key = word , dic = df)    #calculate df
    return tf , df;

# %%
def get_tfidf(tf_list , df , N):
    tfidf_list = []
    for tf in tf_list:
        tfidf = {}
        for (word , tf_value) in tf.items():
            tfidf[word] = tf_value * math.log( N / ( 1 + df[word]) , 2 ) 
        tfidf_list.append(tfidf);
    return tfidf_list

# %%
def solve(EQB):
    df = {}
    tf_list = []
    id_list = []
    N = len(EQB);
    
    item = pd_EOEG['Item'][0] 
    for i in range(len(EQB)):
        EQB_field = EQB[i];
        id = pd_EOEG['Quality Activity'][i] 
        if (pd_EOEG['Item'].isna()[i] == False):
            item = pd_EOEG['Item'][i] 
        
        if len(EQB_field) == 0:
            N = N - 1
            continue    
        tf , df = get_tf(EQB_field, df)
        tf_list.append(tf)
        id_list.append(item + ' ' + id)
    tfidf_list = get_tfidf(tf_list , df , N)
    
    
    for i in range(len(tfidf_list)):
        tfidf = tfidf_list[i]
        id = id_list[i]
        print(id)
        s = pd.Series(tfidf)
        print(s.sort_values(ascending=False).head(10))

# %%
solve(EQB)
# Out:
# 1.1 a. Minimun Vertical Clearance for Access
# walkway     0.453391
# headroom    0.372746
# platform    0.287234
# clearanc    0.253007
# work        0.181357
# overhead    0.149098
# elev        0.149098
# ead         0.106807
# stairway    0.106807
# whichev     0.097372
# dtype: float64
# 1.1 b. Minimun width Clearance for Access
# platform    0.445213
# walkway     0.374803
# width       0.308137
# clearanc    0.261441
# minimum     0.249277
# passag      0.220735
# aisl        0.201236
# escap       0.201236
# arrang      0.167903
# horizont    0.160490
# dtype: float64
# 1.2 a. Maximum distance between landings on a sectional ladder
# platform    0.455331
# ladder      0.411620
# distanc     0.202369
# maximum     0.183504
# run         0.171719
# vertic      0.171719
# mm          0.156915
# offset      0.150501
# tower       0.137207
# meter       0.114479
# dtype: float64
# 1.2 b. Distance from manhole center line to platform
# platform     0.536401
# manhol       0.446998
# mm           0.291143
# bottom       0.182063
# entri        0.145472
# centrelin    0.145472
# prefer       0.135471
# centerlin    0.135471
# elev         0.111375
# posit        0.111375
# dtype: float64
# 1.2 c. Min. manhole center elevation for installing "permanent platform" on vertical equipments(vessel, tower...)
# platform    0.353343
# manway      0.267717
# access      0.264293
# elev        0.220098
# ground      0.159908
# less        0.124496
# requir      0.112209
# stand       0.105112
# movabl      0.105112
# object      0.105112
# dtype: float64
# 1.3 a. Min. overhead clearance is sufficient for pump and motor lift-out
# clearanc    0.594184
# overhead    0.420187
# equip       0.327670
# mobil       0.305278
# similar     0.200668
# lift        0.200668
# aisl        0.182942
# work        0.170365
# hand        0.160610
# vertic      0.152639
# dtype: float64
# 1.3 b. Horizontal heat exchanger piping design:
# Clearance to allow for head cover removal
# clearanc    0.313729
# bonnet      0.264882
# access      0.249757
# general     0.242225
# exchang     0.241484
# end         0.201484
# width       0.184882
# around      0.152588
# clear       0.132441
# channel     0.132441
# dtype: float64
# 1.4 Valve shall be provided at high point test vent
# vent         1.207418
# drain        0.642520
# valv         0.310462
# except       0.237864
# line         0.206974
# plug         0.189201
# screw        0.189201
# hydrotest    0.189201
# cap          0.160630
# pneumat      0.160630
# dtype: float64
# 1.5 Flange type (26" and above)
# asm         0.527067
# flang       0.455287
# seri        0.377318
# inch        0.220912
# smaller     0.175689
# nps         0.175689
# end         0.157409
# otherwis    0.144439
# unless      0.144439
# specifi     0.134379
# dtype: float64
# 1.7 Utility Station variety and sequence (Left→ Right)
# station     0.616293
# util        0.588354
# hose        0.177428
# nitrogen    0.154001
# pipe        0.149824
# standard    0.145208
# typic       0.140397
# column      0.123259
# for         0.120423
# draw        0.117142
# dtype: float64
# 1.8 Safety Shower request
# shower       0.243011
# eye          0.243011
# safeti       0.206314
# station      0.194500
# eyewash      0.182258
# wash         0.121506
# expos        0.121506
# personnel    0.110772
# corros       0.097250
# may          0.088343
# dtype: float64
# 2.1 Pipe racks required space for future lines
# futur       0.344003
# piperack    0.196009
# pipe        0.191241
# sleeper     0.156808
# rack        0.144550
# cabl        0.129001
# process     0.128576
# expans      0.103249
# min         0.090040
# space       0.087240
# dtype: float64
# 2.2 a. Crossing train way
# clearanc    1.307204
# railroad    1.103675
# over        0.883354
# overhead    0.770342
# tabl        0.229021
# dtype: float64
# 2.2 d. Pipe racks for walk way
# walkway       0.733311
# platform      0.387141
# clearanc      0.341010
# passageway    0.262482
# work          0.244437
# establish     0.244437
# head          0.230440
# over          0.230440
# mainten       0.209335
# room          0.209335
# dtype: float64
# 2.2 e. The first level of main pipe rack
# rack         0.445213
# overhead     0.308137
# clearanc     0.261441
# main         0.235639
# pave         0.187402
# establish    0.187402
# pipe         0.184069
# head         0.176671
# beam         0.176671
# bottom       0.167903
# dtype: float64
# 2.4 Distance between two columns
# center     0.670788
# rack       0.494681
# main       0.392732
# mm         0.383570
# maxlmum    0.335394
# prefer     0.312336
# even       0.312336
# column     0.294451
# width      0.256781
# support    0.217867
# dtype: float64
# 2.6 Width of pipe rack
# center     0.670788
# rack       0.494681
# main       0.392732
# mm         0.383570
# maxlmum    0.335394
# prefer     0.312336
# even       0.312336
# column     0.294451
# width      0.256781
# support    0.217867
# dtype: float64
# 2.7 Minimun pipe size on rack/sleeper
# piperack     0.355123
# span         0.355123
# maximum      0.237476
# support      0.230683
# auxiliari    0.194766
# actual       0.194766
# avoid        0.194766
# header       0.177561
# deflect      0.177561
# excess       0.177561
# dtype: float64
# 3.1 Code of straight run for orifice flange
# orific        0.267717
# meter         0.239861
# plate         0.239861
# straight      0.191654
# length        0.191654
# differenti    0.178478
# api           0.168258
# iso           0.105112
# rp550         0.105112
# report        0.105112
# dtype: float64
# 3.2 a. Orifice take off taps for gas, vapor lines
# horizont    0.320980
# tap         0.268315
# upward      0.268315
# orific      0.249869
# servic      0.247677
# meter       0.223871
# plate       0.223871
# licensor    0.134158
# data        0.134158
# orient      0.134158
# dtype: float64
# 3.2 b. Orifice take off taps for liquid lines, or steam lines
# horizont    0.320980
# tap         0.268315
# upward      0.268315
# orific      0.249869
# servic      0.247677
# meter       0.223871
# plate       0.223871
# licensor    0.134158
# data        0.134158
# orient      0.134158
# dtype: float64
# 3.3 Minimun pipe size for thermowell
# inch          0.289720
# swage         0.217116
# immers        0.217116
# thermowel     0.217116
# medium        0.217116
# elbow         0.217116
# temperatur    0.169777
# instrument    0.165150
# diamet        0.151543
# pipe          0.150876
# dtype: float64
# 1.4 a.Heavy vehicle(mobil crane)
# primari     0.804945
# metr        0.749607
# road        0.690425
# entri       0.402473
# overal      0.402473
# shoulder    0.374803
# hard        0.353342
# width       0.308137
# except      0.277508
# main        0.235639
# dtype: float64
# 1.4 b.Light vehicle(truck or car)
# metr         0.937009
# secondari    0.937009
# road         0.863032
# overal       0.503091
# shoulder     0.468504
# hard         0.441677
# width        0.385171
# shall        0.070058
# dtype: float64
# 1.4 c.Fire engine
# metr        0.864931
# road        0.531096
# tertiari    0.509389
# remot       0.464391
# fight       0.464391
# shoulder    0.432466
# hard        0.407702
# width       0.355542
# access      0.320202
# fire        0.163861
# dtype: float64
# 1.5 a.Heavy vehicle(mobil crane)
# overhead    0.513561
# rack        0.494681
# clearanc    0.435735
# road        0.383570
# complex     0.367892
# primari     0.335394
# crown       0.335394
# beam        0.294451
# bottom      0.279838
# headroom    0.256781
# dtype: float64
# 1.5 b.Light vehicle(truck or car)
# overhead     0.440195
# rack         0.424012
# clearanc     0.373487
# road         0.328774
# expect       0.315336
# major        0.315336
# vehicl       0.287480
# crown        0.287480
# secondari    0.267717
# beam         0.252387
# dtype: float64
# 1.8 Maximum escape distance from stair or ladder for structure/pipe rack platform
# platform     0.556516
# three        0.377318
# exit         0.377318
# furthest     0.377318
# escap        0.377318
# secondari    0.351378
# travel       0.331258
# mean         0.331258
# vessel       0.300919
# distanc      0.278258
# dtype: float64
# 2.1 Minimum distance between equipment  to process unit.
# recommend    0.533228
# space        0.497590
# tabl         0.458041
# dtype: float64
# 2.1 a. Flare stack
# recommend    0.533228
# space        0.497590
# tabl         0.458041
# dtype: float64
# 2.1 b. Service Building(non operating)
# recommend    0.533228
# space        0.497590
# tabl         0.458041
# dtype: float64
# 2.1 c. Control room (operating)
# recommend    0.533228
# space        0.497590
# tabl         0.458041
# dtype: float64
# 2.1 d. Cooling tower.
# recommend    0.533228
# space        0.497590
# tabl         0.458041
# dtype: float64
# 2.1 e. Fire water pump
# recommend    0.533228
# space        0.497590
# tabl         0.458041
# dtype: float64
# 2.1 f.  Pressure storage tank.
# recommend    0.533228
# space        0.497590
# tabl         0.458041
# dtype: float64
# 2.1 g. Atmospheric storage tank
# recommend    0.533228
# space        0.497590
# tabl         0.458041
# dtype: float64
# 2.1 h. Refrigerated storage tank
# recommend    0.533228
# space        0.497590
# tabl         0.458041
# dtype: float64
# 2.1 i. Unloading & loading rack
# recommend    0.533228
# space        0.497590
# tabl         0.458041
# dtype: float64
# 2.1 j. MCC and electric substation
# recommend    0.533228
# space        0.497590
# tabl         0.458041
# dtype: float64
# 2.1 k. MCC and electrical substation
# recommend    0.533228
# space        0.497590
# tabl         0.458041
# dtype: float64
# 2.1 l. Compressor building
# recommend    0.533228
# space        0.497590
# tabl         0.458041
# dtype: float64
# 3.1 a. Cooling tower.
# recommend    0.533228
# space        0.497590
# tabl         0.458041
# dtype: float64
# 3.1 b. MCC and electric substation
# recommend    0.533228
# space        0.497590
# tabl         0.458041
# dtype: float64
# 3.1 c. Fire water pump
# recommend    0.533228
# space        0.497590
# tabl         0.458041
# dtype: float64
# 3.1 d. Compressor building
# recommend    0.533228
# space        0.497590
# tabl         0.458041
# dtype: float64
# 3.1 e. Pressure storage tank
# recommend    0.533228
# space        0.497590
# tabl         0.458041
# dtype: float64
# 3.1 f. Service Building(non operating)
# recommend    0.533228
# space        0.497590
# tabl         0.458041
# dtype: float64
# 3.1 g. Control room (operating)
# recommend    0.533228
# space        0.497590
# tabl         0.458041
# dtype: float64
# 3.1 h. Atmospheric storage tank
# recommend    0.533228
# space        0.497590
# tabl         0.458041
# dtype: float64
# 3.1 i. Refrigerated storage tank
# recommend    0.533228
# space        0.497590
# tabl         0.458041
# dtype: float64
# 3.1 j. Unloading & loading rack
# recommend    0.533228
# space        0.497590
# tabl         0.458041
# dtype: float64
# 4.1 a. Service Building (non operating)
# recommend    0.533228
# space        0.497590
# tabl         0.458041
# dtype: float64
# 4.1 b. Control room (operating)
# recommend    0.533228
# space        0.497590
# tabl         0.458041
# dtype: float64
# 4.1 c. MCC and electric substation
# recommend    0.533228
# space        0.497590
# tabl         0.458041
# dtype: float64
# 4.1 d. Compressor building
# recommend    0.533228
# space        0.497590
# tabl         0.458041
# dtype: float64
# 4.1 e. Atmospheric storage tank
# recommend    0.533228
# space        0.497590
# tabl         0.458041
# dtype: float64
# 4.1 f. Pressure storage tank
# recommend    0.533228
# space        0.497590
# tabl         0.458041
# dtype: float64
# 4.1 g.Refrigerated storage tank
# recommend    0.533228
# space        0.497590
# tabl         0.458041
# dtype: float64
# 4.1 h. Unloading & loading rack
# recommend    0.533228
# space        0.497590
# tabl         0.458041
# dtype: float64
# 4.1 i. Fire water pump
# recommend    0.533228
# space        0.497590
# tabl         0.458041
# dtype: float64
# 5.1 a. Compressor building
# recommend    0.533228
# space        0.497590
# tabl         0.458041
# dtype: float64
# 5.1 b. Atmospheric storage tank
# recommend    0.533228
# space        0.497590
# tabl         0.458041
# dtype: float64
# 5.1 c. Pressure storage tank
# recommend    0.533228
# space        0.497590
# tabl         0.458041
# dtype: float64
# 5.1 d. Refrigerated storage tank
# recommend    0.533228
# space        0.497590
# tabl         0.458041
# dtype: float64
# 5.1 e. Unloading and loading rack
# recommend    0.533228
# space        0.497590
# tabl         0.458041
# dtype: float64
# 5.1 f. Flare stack
# recommend    0.533228
# space        0.497590
# tabl         0.458041
# dtype: float64
# 5.1 g. Fire water pump
# recommend    0.533228
# space        0.497590
# tabl         0.458041
# dtype: float64
# 6.1 a. Compressor building
# recommend    0.533228
# space        0.497590
# tabl         0.458041
# dtype: float64
# 6.1 b. Atmospheric storage tank
# recommend    0.533228
# space        0.497590
# tabl         0.458041
# dtype: float64
# 6.1 c. Pressure storage tank
# recommend    0.533228
# space        0.497590
# tabl         0.458041
# dtype: float64
# 6.1 d.Refrigerated storage tank
# recommend    0.533228
# space        0.497590
# tabl         0.458041
# dtype: float64
# 6.1 e. Unloading and loading rack
# recommend    0.533228
# space        0.497590
# tabl         0.458041
# dtype: float64
# 6.1 f. Flare stack
# recommend    0.533228
# space        0.497590
# tabl         0.458041
# dtype: float64
# 6.1 g. Fire water pump
# recommend    0.533228
# space        0.497590
# tabl         0.458041
# dtype: float64
# 7.1 a. Control room ( operating)
# recommend    0.533228
# space        0.497590
# tabl         0.458041
# dtype: float64
# 7.1 b. Atmospheric storage tank
# recommend    0.533228
# space        0.497590
# tabl         0.458041
# dtype: float64
# 7.1 c. Pressure storage tank
# recommend    0.533228
# space        0.497590
# tabl         0.458041
# dtype: float64
# 7.1 d. Refrigerated storage tank
# recommend    0.533228
# space        0.497590
# tabl         0.458041
# dtype: float64
# 7.1 e. Unloading and loading rack
# recommend    0.533228
# space        0.497590
# tabl         0.458041
# dtype: float64
# 7.1 f. Flare stack
# recommend    0.533228
# space        0.497590
# tabl         0.458041
# dtype: float64
# 7.1 g. Fire water pump
# recommend    0.533228
# space        0.497590
# tabl         0.458041
# dtype: float64
# 8.1 a. Fire water pump
# recommend    0.533228
# space        0.497590
# tabl         0.458041
# dtype: float64
# 8.1 b. Unloading and loading rack
# recommend    0.533228
# space        0.497590
# tabl         0.458041
# dtype: float64
# 9.1 a. Reactor
# recommend    0.533228
# space        0.497590
# tabl         0.458041
# dtype: float64
# 9.1 b. Column, Accumulator, Drum
# recommend    0.533228
# space        0.497590
# tabl         0.458041
# dtype: float64
# 9.1 c. Pipe rack
# recommend    0.533228
# space        0.497590
# tabl         0.458041
# dtype: float64
# 9.1 d. Compressor
# recommend    0.533228
# space        0.497590
# tabl         0.458041
# dtype: float64
# 9.1 e. Air cooled heat exchanger
# recommend    0.533228
# space        0.497590
# tabl         0.458041
# dtype: float64
# 9.1 f.  Heat exchanger
# recommend    0.533228
# space        0.497590
# tabl         0.458041
# dtype: float64
# 9.1 g. Rundown tank
# recommend    0.533228
# space        0.497590
# tabl         0.458041
# dtype: float64
# 9.1 h. Analyzer room
# recommend    0.533228
# space        0.497590
# tabl         0.458041
# dtype: float64
# 2.1 Software for  piping stress analysis
# disk          0.575831
# softwar       0.575831
# comput        0.575831
# miscellan     0.287915
# said          0.287915
# pc            0.287915
# stress        0.262482
# contractor    0.244437
# solut         0.244437
# analysi       0.244437
# dtype: float64
# 2.2 Applicable Code for seismic/wind load calculation
# wind         1.049929
# load         0.560886
# philippin    0.287915
# nation       0.287915
# upon         0.287915
# asc          0.287915
# determin     0.262482
# categori     0.262482
# code         0.262482
# speed        0.262482
# dtype: float64
# 2.4 a. Nozzle allowable loads for static equipment
# nozzl     0.476837
# given     0.413878
# valu      0.413878
# claus     0.413878
# replac    0.413878
# ses       0.377318
# moment    0.377318
# no        0.351378
# limit     0.351378
# allow     0.351378
# dtype: float64
# 2.4 b. Calculation temperature for nozzle load check
# temperatur    0.501115
# oper          0.299610
# line          0.292101
# evalu         0.213615
# maximum       0.195343
# moment        0.194745
# movement      0.194745
# calcul        0.181357
# forc          0.170972
# consid        0.170972
# dtype: float64
# 2.4 c. Criteria for nature frequency check
# frequenc      0.646054
# critic        0.323027
# compressor    0.245712
# vendor        0.161513
# order         0.161513
# slug          0.161513
# restrain      0.161513
# natur         0.161513
# agre          0.161513
# reciproc      0.161513
# dtype: float64
# 2.5 The based temperature for thermal expansion for different expansion and settlement due to different equipment
# temperatur    0.908454
# ambient       0.697058
# instal        0.414008
# taken         0.348529
# an            0.348529
# cold          0.278954
# normal        0.253405
# min           0.243266
# servic        0.195535
# line          0.190634
# dtype: float64
# 2.6 a. Pipe size
# friction    0.562205
# effect      0.503709
# long        0.331103
# resist      0.331103
# thermal     0.331103
# movement    0.301854
# anchor      0.281103
# run         0.251854
# larger      0.240735
# horizont    0.240735
# dtype: float64
# 2.6 b. Friction factor for steel to steel
# friction    0.881890
# steel       0.437078
# effect      0.296299
# load        0.252948
# factor      0.236749
# support     0.153789
# reduc       0.118374
# act         0.118374
# coeffici    0.118374
# shown       0.118374
# dtype: float64
# 2.6 c. Friction factor for stainless steel to PTFE
# friction    0.881890
# steel       0.364231
# effect      0.296299
# load        0.252948
# factor      0.236749
# support     0.153789
# teflon      0.129844
# pecifi      0.129844
# reduc       0.118374
# shown       0.118374
# dtype: float64
# 3.2 b. Variability of variable spring
# spring      0.710246
# catalogu    0.389532
# supplier    0.389532
# publish     0.389532
# hanger      0.389532
# chang       0.389532
# deviat      0.389532
# variabl     0.355123
# constant    0.355123
# detail      0.261890
# dtype: float64
# 3.2 (ii) Min. (T.T.-A.T.)/A.T.
# spring      1.149922
# constant    0.574961
# variabl     0.574961
# load        0.409536
# toler       0.315336
# mark        0.315336
# preset      0.315336
# calibr      0.315336
# accept      0.252387
# within      0.239861
# dtype: float64
# 4.1 Max. pipe deflection for pipe support design
# support      0.336138
# slope        0.321260
# design       0.206794
# pocket       0.189201
# sag          0.189201
# half         0.189201
# format       0.172488
# span         0.172488
# withstand    0.172488
# review       0.172488
# dtype: float64
# 4.2 Temperature range of PTFE for  piping special support material
# slide     1.655513
# ptfe      1.405513
# plate     1.259272
# materi    0.790655
# dtype: float64
# 1.1 Sea water in fire fighting system
# dn        0.674646
# sea       0.482967
# frp       0.402967
# ms        0.356170
# all       0.276170
# ug        0.264882
# class     0.253010
# ms19fw    0.241484
# cement    0.241484
# epoxi     0.224882
# dtype: float64
# 2.1.1 Capacity of fire water pond/Tank for fire
# pumps running
# continu    0.509389
# peak       0.509389
# hour       0.509389
# demand     0.464391
# six        0.432466
# suffici    0.432466
# firewat    0.370361
# storag     0.301662
# capac      0.293438
# tank       0.265548
# dtype: float64
# 2.1.3 Standpipe for indoor hydrant
# standpip    1.324410
# class       0.379514
# system      0.373864
# iii         0.264882
# kayan       0.264882
# saudi       0.264882
# indoor      0.264882
# describ     0.241484
# project     0.212005
# ii          0.184882
# dtype: float64
# 2.1.4 Block valve for monitor
# monitor    0.523780
# ball       0.355123
# valv       0.213062
# hydrant    0.198478
# lever      0.194766
# stream     0.194766
# lockabl    0.177561
# adjust     0.177561
# quarter    0.177561
# turn       0.177561
# dtype: float64
# 2.1.5 Max. quantity of branch line between post indicator valves (PIVS)
# main       0.252471
# firewat    0.229271
# fire       0.202876
# time       0.157668
# five       0.157668
# singl      0.157668
# there      0.157668
# outag      0.157668
# block      0.143740
# risk       0.143740
# dtype: float64
# 2.1.6 Hydrant space
# hydrant      0.586804
# roadway      0.524964
# along        0.488874
# accessway    0.287915
# tankag       0.287915
# administr    0.287915
# util         0.244437
# area         0.228005
# way          0.209335
# measur       0.209335
# dtype: float64
# 2.2.1 Water spray requirement
# handl       0.294451
# spray       0.256781
# liquid      0.171187
# water       0.140170
# flammabl    0.133742
# fix         0.128390
# c4          0.122631
# lighter     0.122631
# system      0.108178
# equip       0.100121
# dtype: float64
# 2.2.2 Water Spray System Actuation & Detection method.
# delug      0.367223
# oper       0.251875
# valv       0.245563
# actuat     0.238223
# via        0.224476
# spray      0.156680
# automat    0.134749
# system     0.118813
# manual     0.113190
# button     0.102324
# dtype: float64
# 2.2.3 a. Tank
# pmd       0.275919
# specif    0.220912
# cool      0.220838
# layout    0.209879
# liquid    0.192585
# storag    0.163401
# plant     0.154798
# tank      0.143839
# outlin    0.137959
# water     0.135164
# dtype: float64
# 2.2.3 b. Process equipment
# liquid      0.318762
# storag      0.270456
# entir       0.228347
# class       0.218112
# flash       0.208175
# cool        0.182763
# combust     0.182763
# vessel      0.166024
# flammabl    0.166024
# horizont    0.166024
# dtype: float64
# 2.3.1 Foam system requirement
# foam          0.454740
# epc           0.166942
# contractor    0.141732
# tank          0.116038
# rotor         0.111295
# pump          0.101775
# capabl        0.101464
# deliv         0.089078
# select        0.089078
# instal        0.088136
# dtype: float64
# 2.3.2 Foam tank outside protction
# foam       0.396440
# nozzl      0.363304
# nstead     0.315336
# shade      0.315336
# convent    0.315336
# associ     0.287480
# sun        0.287480
# where      0.267717
# drum       0.267717
# handl      0.252387
# dtype: float64
# 2.3.3 a. Fixed roof tank containing hydrocarbons
# foam         0.693770
# system       0.292081
# full         0.251545
# roof         0.251545
# solut        0.234252
# complianc    0.234252
# expans       0.220838
# low          0.200612
# liquid       0.192585
# nfpa         0.192585
# dtype: float64
# 2.3.3 b. Open floating roof tank seal area
# foam         0.693770
# system       0.389442
# float        0.367892
# roof         0.335394
# full         0.335394
# complianc    0.312336
# expans       0.294451
# seal         0.267483
# low          0.267483
# nfpa         0.256781
# dtype: float64
# 2.4.1 Water curtain requirement
# curtain    0.710246
# cloud      0.389532
# vapour     0.389532
# inciner    0.389532
# boiler     0.389532
# sourc      0.389532
# ignit      0.389532
# format     0.355123
# furnac     0.355123
# event      0.330709
# dtype: float64
# 2.4.2 Water curtain system actuation & detection method.
# actuat     0.401575
# link       0.287480
# pneumat    0.267717
# fusibl     0.267717
# delug      0.229271
# without    0.157668
# curtain    0.143740
# button     0.143740
# push       0.143740
# pilot      0.133858
# dtype: float64
# 2.5.1 Selection of detector
# detect     1.439168
# fire       0.608628
# summari    0.530737
# system     0.333807
# tabl       0.196303
# dtype: float64
# 3 Fire extinguisher
# extinguish    0.770352
# portabl       0.369764
# protect       0.289764
# proof         0.264882
# weather       0.264882
# kept          0.264882
# fire          0.255624
# throughout    0.241484
# dust          0.224882
# facil         0.224882
# dtype: float64
# 3.1 Dry chemical
# extinguish    0.722205
# fire          0.319530
# dri           0.312197
# chemic        0.251854
# wheel         0.251854
# portabl       0.231103
# attack        0.165551
# held          0.165551
# dioxid        0.165551
# fight         0.150927
# dtype: float64
# 4 Clash prevention for F/F equipment
# post        0.624722
# guard       0.499777
# monitor     0.252007
# mechan      0.227815
# damag       0.227815
# protect     0.205022
# hydrant     0.190988
# locat       0.179016
# obstruct    0.124944
# need        0.124944
# dtype: float64
# 5.1 Approval of F/F equipment (UL.,FM,local authorized)
# pump         0.217048
# list         0.179037
# ul           0.162487
# fm           0.162487
# control      0.134278
# firefight    0.129830
# refer        0.095745
# fire         0.091621
# approv       0.089519
# standard     0.089519
# dtype: float64
# 5.2 Outdoor hydrant
# requir     1.767294
# hydrant    1.687062
# dtype: float64
# 5.2.1 Hose nozzle size
# connect    0.401918
# hydrant    0.195601
# pumper     0.174988
# hose       0.165856
# valv       0.157481
# inch       0.153678
# outlet     0.153627
# gate       0.153627
# fire       0.123490
# two        0.113670
# dtype: float64
# 5.2.2 Pumper nozzle size
# connect    0.361098
# gate       0.331258
# pumper     0.282989
# outlet     0.248443
# valv       0.226378
# hydrant    0.210883
# inch       0.165684
# fire       0.133137
# two        0.122550
# hose       0.119209
# dtype: float64
# 5.2.3 Inlet conn. size
# hydrant    0.421766
# connect    0.288878
# fire       0.266275
# valv       0.150919
# barrel     0.137959
# face       0.137959
# grid       0.137959
# inlet      0.137959
# tobs336    0.137959
# flat       0.137959
# dtype: float64
# 5.3.1 Hose cabinet contents
# hose       0.435965
# box        0.327628
# type       0.163838
# foam       0.158576
# two        0.149395
# nozzl      0.108991
# can        0.107087
# contain    0.081907
# each       0.074697
# shall      0.064053
# dtype: float64
# 5.3.2 Fire hose size & length
# hose       0.435965
# box        0.327628
# type       0.163838
# foam       0.158576
# two        0.149395
# nozzl      0.108991
# can        0.107087
# contain    0.081907
# each       0.074697
# shall      0.064053
# dtype: float64
# 5.3.3 a. Flow rate
# hose     0.453231
# box      0.425755
# doubl    0.119546
# two      0.116484
# can      0.111328
# type     0.085163
# shall    0.083237
# foam     0.082428
# each     0.077656
# nozzl    0.075539
# dtype: float64
# 5.3.3 b. Effective distance
# hose         0.501934
# box          0.452645
# doubl        0.317742
# fire         0.168174
# color        0.158871
# hing         0.158871
# red          0.158871
# coupl        0.147949
# dust         0.147949
# construct    0.147949
# dtype: float64
# 5.4.1 Hose cabinet contents
# hose      0.469501
# box       0.396934
# type      0.264661
# two       0.120665
# locat     0.097311
# shall     0.090536
# area      0.080679
# minut     0.077494
# liter     0.077494
# provid    0.076701
# dtype: float64
# 5.4.2 Fire hose size & length
# hose      0.500288
# box       0.422963
# type      0.282016
# two       0.128577
# locat     0.103692
# shall     0.096473
# area      0.085969
# provid    0.081730
# store     0.075771
# besid     0.075771
# dtype: float64
# 5.4.3 a. Size
# hose      0.500288
# box       0.422963
# type      0.282016
# two       0.128577
# locat     0.103692
# shall     0.096473
# area      0.085969
# provid    0.081730
# store     0.075771
# besid     0.075771
# dtype: float64
# 5.4.3 b. Flow rate
# hose      0.423855
# box       0.409536
# type      0.273063
# two       0.124496
# locat     0.100401
# shall     0.093410
# area      0.083240
# minut     0.079954
# liter     0.079954
# provid    0.079136
# dtype: float64
# 5.5.1 Flow rate
# bar        1.324410
# lpm        0.962939
# monitor    0.890425
# capac      0.762939
# fire       0.426040
# dtype: float64
# 5.6.1 Valve type
# valv           0.552516
# block          0.409294
# gate           0.269498
# isol           0.269498
# fulli          0.204647
# indic          0.204647
# main           0.179725
# posit          0.156680
# underground    0.156680
# ring           0.156680
# dtype: float64
# 5.7.1 Type of fuse
# loop         0.794646
# fusibl       0.674646
# devic        0.424010
# detect       0.402967
# integr       0.264882
# consist      0.224882
# part         0.224882
# pilot        0.224882
# sprinkler    0.212005
# delug        0.192588
# dtype: float64
# 5.8.1 Inlet size
# truck      0.263819
# fire       0.175085
# provis     0.121976
# water      0.118500
# hose       0.104512
# least      0.096838
# chassi     0.090713
# readili    0.090713
# sohar      0.090713
# cracker    0.090713
# dtype: float64
# 5.8.2 Outlet size
# truck    2.407348
# fire     1.065099
# dtype: float64
# 5.9.1 Type of foam concentrate for hydrocarbon fire
# foam       0.535194
# aqueous    0.189201
# afff       0.189201
# film       0.189201
# fp         0.189201
# form       0.160630
# applic     0.137563
# protect    0.103487
# tank       0.098632
# treat      0.094601
# dtype: float64
# 5.10.1 a. Agent
# extinguish    0.396504
# portabl       0.217508
# kg            0.187063
# chemic        0.177780
# fire          0.175428
# dri           0.146916
# small         0.142049
# potassium     0.132284
# bicarbon      0.132284
# mount         0.118520
# dtype: float64
# 5.10.1 b. Capacity
# extinguish    0.409761
# kg            0.225537
# chemic        0.214344
# portabl       0.196683
# fire          0.181294
# potassium     0.179427
# bicarbon      0.179427
# dri           0.177133
# small         0.128449
# bc            0.128449
# dtype: float64
# 5.10.1 c. Rating
# extinguish    0.401225
# gaug          0.234252
# substat       0.234252
# potassium     0.234252
# warehous      0.234252
# bicarbon      0.234252
# monnex        0.234252
# kg            0.220838
# wheel         0.209879
# suitabl       0.200612
# dtype: float64
# 5.10.2 a. Capacity
# co            0.522794
# extinguish    0.506810
# electr        0.209215
# fire          0.196203
# portabl       0.182449
# travel        0.139477
# nfpa          0.121633
# distanc       0.117161
# build         0.103200
# leav          0.087132
# dtype: float64
# 5.11.1 Standard and code
# firewat    0.687814
# pump       0.576727
# turbin     0.315336
# motor      0.315336
# diesel     0.315336
# driven     0.315336
# engin      0.267717
# conform    0.252387
# accept     0.252387
# electr     0.252387
# dtype: float64
# 5.11.1 c. Approval required (UL, FM,local authorized) for
# pump         0.403709
# list         0.208131
# control      0.208131
# fire         0.177517
# fm           0.167903
# ul           0.167903
# approv       0.138754
# water        0.108131
# underwrit    0.083951
# up           0.083951
# dtype: float64
# 5.11.1 Fire pump
# pump         0.403709
# list         0.208131
# control      0.208131
# fire         0.177517
# fm           0.167903
# ul           0.167903
# approv       0.138754
# water        0.108131
# underwrit    0.083951
# up           0.083951
# dtype: float64
# 5.11.1 Engine
# pump         0.403709
# list         0.208131
# control      0.208131
# fire         0.177517
# fm           0.167903
# ul           0.167903
# approv       0.138754
# water        0.108131
# underwrit    0.083951
# up           0.083951
# dtype: float64
# 5.11.1 Controller
# pump         0.403709
# list         0.208131
# control      0.208131
# fire         0.177517
# fm           0.167903
# ul           0.167903
# approv       0.138754
# water        0.108131
# underwrit    0.083951
# up           0.083951
# dtype: float64
# 5.11.2 a. Capacity
# pump        0.492328
# head        0.387814
# rate        0.304582
# less        0.191298
# ani         0.161513
# fire        0.155868
# shutoff     0.147246
# review      0.147246
# individu    0.147246
# subject     0.147246
# dtype: float64
# 5.11.2 b. Head
# head       0.424010
# pump       0.403709
# rate       0.249757
# demand     0.241484
# maximum    0.161484
# capac      0.152588
# assum      0.132441
# worst      0.132441
# the        0.131747
# water      0.129757
# dtype: float64
# 1.1.1 Manhole vent
# vent      0.548826
# manhol    0.481829
# for       0.313830
# aoc       0.255548
# ow        0.255548
# draw      0.228959
# see       0.228959
# sewer     0.218850
# cs        0.210093
# diamet    0.210093
# dtype: float64
# 1.1.2 Min. sewer line branch
# drain         0.759737
# funnel        0.357949
# sewer         0.260254
# oili          0.178974
# collect       0.163165
# principl      0.163165
# downstream    0.151947
# ow            0.151947
# aoc           0.151947
# sewag         0.136138
# dtype: float64
# 1.1.3 Min. catch basin outlet
# size       0.505897
# drainag    0.296299
# sewer      0.283217
# minimum    0.219950
# requir     0.207917
# rainfal    0.194766
# sump       0.194766
# met        0.194766
# storm      0.194766
# while      0.194766
# dtype: float64
# 1.2.1 Manway
# main           0.321326
# buri           0.240915
# depth          0.228959
# cover          0.218850
# measur         0.218850
# ring           0.210093
# underground    0.210093
# water          0.196602
# top            0.195460
# fire           0.193654
# dtype: float64
# 1.2.2 Light vehicle way(<10 tons)
# main           0.321326
# buri           0.240915
# depth          0.228959
# cover          0.218850
# measur         0.218850
# ring           0.210093
# underground    0.210093
# water          0.196602
# top            0.195460
# fire           0.193654
# dtype: float64
# 1.2.3 Vehicle way (10~20 tons)
# main           0.321326
# buri           0.240915
# depth          0.228959
# cover          0.218850
# measur         0.218850
# ring           0.210093
# underground    0.210093
# water          0.196602
# top            0.195460
# fire           0.193654
# dtype: float64
# 1.2.4 Railroad way
# main           0.321326
# buri           0.240915
# depth          0.228959
# cover          0.218850
# measur         0.218850
# ring           0.210093
# underground    0.210093
# water          0.196602
# top            0.195460
# fire           0.193654
# dtype: float64
# 1.3 Max. interval distance of manhole for
# manhol      0.530012
# sewer       0.288882
# apart       0.264882
# main        0.212075
# drainag     0.201484
# area        0.157323
# junction    0.132441
# various     0.132441
# longer      0.132441
# separ       0.132441
# dtype: float64
# 1.4.1 Each area drain
# drainag    0.335806
# arrang     0.335806
# spread     0.220735
# furnac     0.201236
# anoth      0.201236
# sleeper    0.201236
# away       0.201236
# drain      0.187402
# prevent    0.187402
# pave       0.187402
# dtype: float64
# 1.4.2 Each catch basin
# basin       0.524964
# catch       0.524964
# pave        0.293324
# area        0.205204
# slope       0.146662
# point       0.140420
# drainag     0.131402
# m2          0.115166
# maximum     0.105315
# approxim    0.104993
# dtype: float64
# 1.5 U/G piping under railway
# specif       0.614711
# excav        0.287915
# burial       0.287915
# backfil      0.287915
# prepar       0.287915
# specfic      0.287915
# site         0.262482
# ses          0.262482
# no           0.244437
# construct    0.244437
# dtype: float64
# 1.1 Instrument air material for downstream of filter
# instrument    0.397665
# cs            0.243266
# ms            0.234322
# air           0.226322
# grade         0.200774
# pipe          0.193757
# inch          0.186031
# a106          0.174265
# sch80         0.174265
# plain         0.174265
# dtype: float64
# 1.2 a. for A/G
# ms         0.636018
# class      0.451803
# cool       0.378580
# close      0.343907
# cs         0.330147
# summari    0.265369
# pipe       0.262956
# mm         0.246580
# unit       0.204797
# system     0.166904
# dtype: float64
# 1.2 b. for U/G
# ms         0.636018
# class      0.451803
# cool       0.378580
# close      0.343907
# cs         0.330147
# summari    0.265369
# pipe       0.262956
# mm         0.246580
# unit       0.204797
# system     0.166904
# dtype: float64
# 1.3 a. for A/G
# cs          0.420187
# ff          0.305278
# ms          0.269826
# ca          0.200668
# water       0.196602
# class       0.191674
# upstream    0.182942
# ag          0.182942
# ms02        0.170365
# of          0.170365
# dtype: float64
# 1.3 b. for  U/G
# ring       0.315140
# main       0.240995
# ms         0.202369
# water      0.196602
# accord     0.173395
# regul      0.150501
# hdpe       0.150501
# densiti    0.150501
# fire       0.145241
# class      0.143755
# dtype: float64
# 1.3 c. for down stream of deluge valve
# pipe      0.177416
# class     0.152415
# ms02      0.135471
# water     0.130278
# galvan    0.127714
# delug     0.116017
# system    0.112610
# cs        0.111375
# ms        0.107280
# carbon    0.107280
# dtype: float64
# 1.4.1 Steam tracing tubing material selection
# tube          0.494843
# soft          0.325675
# trace         0.325675
# tracer        0.276494
# steel         0.243617
# anneal        0.217116
# copper        0.197937
# stainless     0.173775
# temperatur    0.169777
# product       0.157859
# dtype: float64
# 1.4.2 Steam tracer (pre-insulation) material regulation
# tube         0.862441
# steel        0.530737
# compress     0.473004
# materi       0.451803
# copper       0.431221
# tracer       0.401575
# stainless    0.378580
# fit          0.359792
# carbon       0.318009
# type         0.204797
# dtype: float64
# 1.5 b. Corrosive Process Sewer Material
# ms         0.593617
# quench     0.441470
# class      0.421683
# epoxi      0.374803
# dn         0.374803
# chemic     0.335806
# frp        0.335806
# summari    0.247677
# pipe       0.245426
# unit       0.191144
# dtype: float64
# 1.6 Series No. for flange size larger than 24"
# asm         0.527067
# flang       0.455287
# seri        0.377318
# inch        0.220912
# smaller     0.175689
# nps         0.175689
# end         0.157409
# otherwis    0.144439
# unless      0.144439
# specifi     0.134379
# dtype: float64
# 1.8 Valve Special Requirement
# servic      0.639168
# ºc          0.213615
# practic     0.142410
# a262        0.142410
# magnif      0.142410
# observ      0.142410
# ºf          0.142410
# granular    0.142410
# inter       0.142410
# per         0.130229
# dtype: float64
# 2.1 PMI Requirement
# identif     0.648698
# posit       0.533314
# pmi         0.509389
# alloy       0.432466
# materi      0.364918
# verif       0.254694
# inspect     0.232196
# document    0.232196
# number      0.203851
# level       0.203851
# dtype: float64
# 3.1 Thickness of C.S.piping
# digit     0.194745
# carbon    0.191489
# note      0.170972
# weld      0.170972
# steel     0.159792
# pipe      0.158339
# alloy     0.120904
# for       0.111359
# mm        0.111359
# fit       0.108325
# dtype: float64
# 3.2 Thickness of A.S.piping
# digit     0.292117
# weld      0.256458
# carbon    0.215425
# alloy     0.181357
# steel     0.179766
# mm        0.167038
# fit       0.162487
# pipe      0.148443
# class     0.102020
# fourth    0.097372
# dtype: float64
# 4.1 Allow Field  Welding of Hot Dip Galv. Piping  (Yes/No)
# galvan    0.908593
# extern    0.321260
# surfac    0.224092
# dip       0.189201
# a153      0.189201
# paint     0.189201
# clean     0.172488
# field     0.172488
# zinc      0.172488
# free      0.172488
# dtype: float64
# 4.2 Bolt Tensioning Require
# procedur    0.827756
# connect     0.577756
# tension     0.413878
# torqu       0.413878
# bolt        0.413878
# scope       0.413878
# this        0.351378
# flang       0.260164
# requir      0.220912
# instal      0.163878
# dtype: float64
# 1.1.5 Extrusion tape
# coat           0.562205
# layer          0.452782
# polyethylen    0.301854
# extern         0.281103
# specif         0.265094
# conflict       0.165551
# pe             0.165551
# polymer        0.165551
# din            0.165551
# supplement     0.165551
# dtype: float64
# 1.2.1 Primer, anti-corrosion
# primer     0.423655
# abras      0.232353
# inner      0.211828
# tape       0.211828
# suitabl    0.168937
# surfac     0.137600
# rubber     0.116176
# bond       0.116176
# dissolv    0.116176
# organ      0.116176
# dtype: float64
# 1.2.2 Cold applied wrap tape (AWWA C209)
# wrap        1.102363
# tape        0.710246
# equival     0.473497
# polyken     0.473497
# outer       0.389532
# inner       0.355123
# joint       0.259688
# field       0.236749
# straight    0.236749
# weld        0.207848
# dtype: float64
# 1.3.1 Holiday test (NACE RP-02-74)
# holiday       0.685040
# electrod      0.456693
# detector      0.387728
# test          0.296560
# artifici      0.228347
# creat         0.228347
# discontinu    0.228347
# feed          0.228347
# kv            0.228347
# voltag        0.228347
# dtype: float64
# 2.1.1 Hot Insulation materials
# hot        0.392236
# insul      0.322469
# wool       0.308002
# miner      0.308002
# materi     0.294197
# approv     0.193610
# specif     0.164399
# perlit     0.154001
# silic      0.154001
# calcium    0.154001
# dtype: float64
# 2.1.2 Cold Insulation materials
# insul            0.550244
# cold             0.378580
# polyisocyanur    0.315336
# glass            0.315336
# elastomer        0.315336
# materi           0.301202
# foam             0.297330
# specifi          0.204768
# appli            0.186743
# specif           0.168314
# dtype: float64
# 2.2.1 Piping
# jacket        0.646831
# aluminum      0.431221
# od            0.215610
# barrier       0.215610
# moistur       0.215610
# polysurlyn    0.215610
# restrict      0.200788
# para          0.189290
# thick         0.179896
# see           0.179896
# dtype: float64
# 2.2.2 Equipment
# jacket        0.670788
# aluminum      0.447192
# barrier       0.223596
# moistur       0.223596
# polysurlyn    0.223596
# restrict      0.208224
# para          0.196301
# thick         0.186559
# smooth        0.186559
# see           0.186559
# dtype: float64
# 2.5.1 Hot insulation
# appendix    0.756840
# stagger     0.602005
# layer       0.548826
# greater     0.548826
# note        0.481829
# thick       0.457917
# insul       0.420187
# two         0.356510
# appli       0.356510
# shall       0.076427
# dtype: float64
# 2.5.2 Cold insulation
# thick     0.719584
# insul     0.660293
# exceed    0.560230
# specif    0.504941
# materi    0.451803
# use       0.409595
# shall     0.120099
# dtype: float64
# 2.6.1 Ambient temperature, annual average
# temperatur    0.552340
# bulb          0.424010
# humid         0.385176
# relat         0.385176
# condit        0.385176
# air           0.344010
# blower        0.212005
# daili         0.212005
# averag        0.212005
# meteorolog    0.212005
# dtype: float64
# 2.6.2 b. Personnel protection, maximum allowable temp.
# pp            0.882940
# insul         0.616274
# surfac        0.522882
# satisfi       0.441470
# personnel     0.402473
# condit        0.320980
# appli         0.261441
# protect       0.241470
# temperatur    0.230142
# follow        0.158275
# dtype: float64
# 2.7 Wind Speed, annual average
# temperatur    0.552340
# bulb          0.424010
# humid         0.385176
# relat         0.385176
# condit        0.385176
# air           0.344010
# blower        0.212005
# daili         0.212005
# averag        0.212005
# meteorolog    0.212005
# dtype: float64
# 2.8.1 Ambient temperature, annual average
# temperatur    0.552340
# bulb          0.424010
# humid         0.385176
# relat         0.385176
# condit        0.385176
# air           0.344010
# blower        0.212005
# daili         0.212005
# averag        0.212005
# meteorolog    0.212005
# dtype: float64
# 2.8.2 Wind Speed, annual average
# wind        0.862441
# vol         0.473004
# nscp        0.473004
# other       0.431221
# categori    0.431221
# occup       0.431221
# speed       0.431221
# ii          0.330147
# basic       0.330147
# edit        0.307152
# dtype: float64
# 2.8.3 Relative humidity, annual average
# temperatur    0.552340
# bulb          0.424010
# humid         0.385176
# relat         0.385176
# condit        0.385176
# air           0.344010
# blower        0.212005
# daili         0.212005
# averag        0.212005
# meteorolog    0.212005
# dtype: float64
